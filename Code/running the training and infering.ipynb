# %% [markdown]
# set up env

# %%
conda env config vars set nnUNet_raw= C:\Users\kramerlab\Documents\nnUnet\nnUNet_raw
conda env config vars set nnUNet_preprocessed= C:\Users\kramerlab\Documents\nnUnet\nnUNet_preprocessed
conda env config vars set nnUNet_results=C:\Users\kramerlab\Documents\nnUnet\nnUNet_results


set nnUNet_preprocessed=C:/Users/kramerlab/Documents/nnUnet/nnUNet_preprocessed
set nnUNet_raw=C:/Users/kramerlab/Documents/nnUnet/nnUNet_raw
set nnUNet_results=C:/Users/kramerlab/Documents/nnUnet/nnUNet_results


C:\Users\kramerlab\Documents\nnUnet\nnUNet_raw

# having issues with the triton installation... from https://github.com/MIC-DKFZ/nnUNet/issues/2115 this command seems to solve the issue?
set nnUNet_compile = f

# training command
nnUNetv2_train  345 3d_fullres 1


# predicting the testing set
nnUNetv2_predict -d Dataset345_BNST -i C:\Users\kramerlab\Documents\nnUnet\nnUNet_raw\Dataset345_BNST\imagesTs -o C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\test_results_1 -f  0 1 2 3 4 -tr nnUNetTrainer -c 3d_fullres -p nnUNetPlans --save_probabilities


# post processing
nnUNetv2_apply_postprocessing -i C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\test_results_1 -o C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\post_processing_results -pp_pkl_file C:/Users/kramerlab/Documents/nnUnet/nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\crossval_results_folds_0_1_2_3_4\postprocessing.pkl -np 8 -plans_json C:/Users/kramerlab/Documents/nnUnet/nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\crossval_results_folds_0_1_2_3_4\plans.json


# evaluating the testing set
nnUNetv2_evaluate_folder C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\gt C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\pred -djfile C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\dataset.json -pfile C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\plans.json


# odd shape masks BNST 24,



nnUNetv2_predict -d Dataset345_BNST -i C:\Users\kramerlab\Documents\nnUnet\nnUNet_raw\Dataset345_BNST\imagesTs -o C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\pred -f  0 1 2 3 4 -tr nnUNetTrainer -c 3d_fullres -p nnUNetPlans --save_probabilities


nnUNetv2_evaluate_folder C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\gt C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\pred -djfile C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\dataset.json -pfile C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\plans.json


nnUNetv2_train  345 3d_fullres 0

## APPLY post processing

nnUNetv2_apply_postprocessing -i C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\pred -o C:\Users\kramerlab\Documents\nnUnet\nnUNet_results\Dataset345_BNST\results_against_testing_set\post_processing -pp_pkl_file C:/Users/kramerlab/Documents/nnUnet/nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\crossval_results_folds_0_1_2_3_4\postprocessing.pkl -np 8 -plans_json C:/Users/kramerlab/Documents/nnUnet/nnUNet_results\Dataset345_BNST\nnUNetTrainer__nnUNetPlans__3d_fullres\crossval_results_folds_0_1_2_3_4\plans.json
